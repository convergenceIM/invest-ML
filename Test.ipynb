# %% [markdown]
# ## This is a test
# This is only a test of the Pelican integration to jupyter notebook

# %%
import random
from functools

random.randint(0,100)
# Out:
# 38

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.hist([10,5,7,10,1,1,2,3,5])
# Out:
# (array([2., 1., 1., 0., 2., 0., 1., 0., 0., 2.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %%
import pandas as pd
import pandas_datareader.data as web

# %%
df = web.DataReader('SPY', 'iex',start='2014-01-01')
df.tail()
# Out:
# 5y
#               open      high     low   close     volume
# date
# 2018-04-23  267.26  267.8900  265.35  266.57   65557954
# 2018-04-24  267.73  267.9762  261.28  262.98  112885452
# 2018-04-25  262.91  264.1300  260.85  263.63  103756753
# 2018-04-26  264.79  267.2452  264.29  266.31   67731942
# 2018-04-27  267.00  267.3400  265.50  266.56   57053647

# %%
X.describe()
# Out:
#                f_0          f_1          f_2          f_3          f_4  \
# count  2557.000000  2557.000000  2557.000000  2557.000000  2557.000000
# mean     -0.000164    -0.000003    -0.000383     0.000090    -0.000282
# std       0.008630     0.013059     0.014165     0.013925     0.010901
# min      -0.030379    -0.039869    -0.046374    -0.046541    -0.034909
# 25%      -0.005963    -0.009250    -0.009761    -0.009459    -0.007598
# 50%      -0.000387     0.000098    -0.000614     0.000114    -0.000195
# 75%       0.005866     0.008982     0.009135     0.009570     0.006859
# max       0.033470     0.037722     0.050989     0.053278     0.041549
#
#                f_5          f_6          f_7          f_8          f_9
# count  2557.000000  2557.000000  2557.000000  2557.000000  2557.000000
# mean      0.000276     0.000024     0.000051    -0.000083     0.000153
# std       0.011587     0.014179     0.011911     0.013130     0.012360
# ...

# %%
from sklearn.datasets import make_regression
dates = pd.date_range(start='2010-01-01',end='2016-12-31')
num_dates = len(dates)
num_features = 10
X_vals,y_vals,coef = make_regression(n_samples=num_dates,effective_rank =3,\
                                     n_features=num_features,n_informative=num_features//2,coef=True,bias=0.1,noise=1.0)

X = pd.DataFrame(X_vals,index=dates)
y = pd.Series(y_vals,index=dates)
y.name = 'actual'
X.columns = ['f_'+str(i) for i in range(num_features)]
X.shape
# Out:
# (2557, 10)

# %%
from invest_ml import data_funcs
from importlib import reload
reload(data_funcs)
X,y = data_funcs.make_data_regression(num_features=20,num_informative=2,effective_rank=1,noise=10,bias=0.1)

# %%
X.describe()
# Out:
#                f_0          f_1          f_2          f_3          f_4  \
# count  2557.000000  2557.000000  2557.000000  2557.000000  2557.000000
# mean      0.000275    -0.000093    -0.000007     0.000062     0.000081
# std       0.009391     0.008850     0.009698     0.011386     0.010249
# min      -0.031038    -0.028063    -0.036997    -0.035119    -0.033544
# 25%      -0.006091    -0.005839    -0.006375    -0.007717    -0.006839
# 50%       0.000566     0.000246     0.000020    -0.000068    -0.000333
# 75%       0.006621     0.005959     0.006616     0.007698     0.007060
# max       0.033334     0.030029     0.037461     0.034721     0.035455
#
#                f_5          f_6          f_7          f_8          f_9  \
# count  2557.000000  2557.000000  2557.000000  2557.000000  2557.000000
# mean      0.000196     0.000126     0.000107     0.000210     0.000270
# std       0.009459     0.011101     0.007076     0.009033     0.007957
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X,y)
lm.score(X,y)
# Out:
# 0.20360038437672712

# %%
y_pred = pd.Series(lm.predict(X),index=dates)
y_pred.name = 'y_pred'
y_pred.hist()

# %%
both = pd.concat([y,y_pred],axis=1)
both.plot.scatter(x='y_pred',y='y_true',alpha=0.2,marker=5)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,shuffle=False)

# %%
X_test
# Out:
#                  f_0       f_1       f_2       f_3       f_4       f_5  \
# 2015-08-08  0.005713  0.009314  0.008621  0.010315 -0.002178 -0.000109
# 2015-08-09 -0.005041 -0.001215 -0.027771  0.018468  0.012163 -0.000660
# 2015-08-10 -0.014122 -0.003847 -0.002380 -0.002563 -0.019262 -0.010477
# 2015-08-11 -0.011091  0.008444  0.024279 -0.015797 -0.005806 -0.018726
# 2015-08-12  0.004897  0.012919  0.014495 -0.004816  0.006663  0.017058
# 2015-08-13 -0.002458  0.005483  0.011092 -0.022155 -0.000735 -0.001309
# 2015-08-14 -0.020204 -0.012799  0.001641  0.014893  0.011630  0.002670
# 2015-08-15 -0.006768  0.019771  0.002692  0.000653 -0.003233 -0.012478
# 2015-08-16 -0.019738 -0.000611  0.007757  0.015260 -0.006540 -0.000008
# 2015-08-17  0.008355 -0.001549  0.026503 -0.001493  0.018552  0.010719
# 2015-08-18 -0.017213  0.001654  0.005687 -0.008324 -0.013264  0.009798
# 2015-08-19 -0.015469 -0.003919  0.008137  0.006894 -0.015071  0.009431
# ...
